# %% [markdown]
# # MEU DESENVOLVIMENTO DE DADOS

# %% [markdown]
# ### Importando as bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Criando dataframe

# %%
dataframe = pd.DataFrame({'Coluna 1':[10,25,5],
                          'Coluna 2':[22,100,12],
                          'Coluna 3':[40,25,1]
                         })

# %%
dataframe
# Out:
#    Coluna 1  Coluna 2  Coluna 3
# 0        10        22        40
# 1        25       100        25
# 2         5        12         1

# %% [markdown]
# ### Carregamento de base de dados

# %%
base_dados = pd.read_csv('C:\\Users\\diego.araujo\\Desktop\\iw training-Pixels\\tabelas\\1\\base_produto.csv')

# %%
base_dados
# Out:
#    Id                    NOME   preço  Id_categoria
# 0   1                    Bola    35.0           1.0
# 1   2                Patinete   120.0           1.0
# 2   3                Carrinho     NaN           1.0
# 3   4                   Skate   296.0           1.0
# 4   5                     NaN  3500.0           2.0
# 5   6           Monitor LG 19   450.0           2.0
# 6   7  O Diário de Anne Frank    45.0           NaN
# 7   8        O dia do Curinga    65.0           3.0
# 8   9        O mundo de Sofia     NaN           3.0
# 9  10      Através do Espelho    38.0           3.0

# %%
#base_dados.head(3)
#base_dados.tail(3)
#base_dados.shape
#base_dados.count()
#base_dados.value_counts()
#base_dados.describe()
#base_dados.dtypes
#base_dados.columns
#base_dados.isna().sum()
#base_dados['Id_categoria'].unique()
# Out:
# array([ 1.,  2., nan,  3.])

# %%
base_dados[['NOME','preço']]
# Out:
#                      NOME   preço
# 0                    Bola    35.0
# 1                Patinete   120.0
# 2                Carrinho     NaN
# 3                   Skate   296.0
# 4                     NaN  3500.0
# 5           Monitor LG 19   450.0
# 6  O Diário de Anne Frank    45.0
# 7        O dia do Curinga    65.0
# 8        O mundo de Sofia     NaN
# 9      Através do Espelho    38.0

# %%
base_dados
# Out:
#    Id                    NOME   preço  Id_categoria
# 0   1                    Bola    35.0           1.0
# 1   2                Patinete   120.0           1.0
# 2   3                Carrinho     NaN           1.0
# 3   4                   Skate   296.0           1.0
# 4   5                     NaN  3500.0           2.0
# 5   6           Monitor LG 19   450.0           2.0
# 6   7  O Diário de Anne Frank    45.0           NaN
# 7   8        O dia do Curinga    65.0           3.0
# 8   9        O mundo de Sofia     NaN           3.0
# 9  10      Através do Espelho    38.0           3.0

# %%
base_dados.rename(columns={'Id':'id','NOME':'nome','preço':'preco','Id_categoria':'id_categoria'},inplace=True)

# %%
base_dados
# Out:
#    id                    nome   preco  id_categoria
# 0   1                    Bola    35.0           1.0
# 1   2                Patinete   120.0           1.0
# 2   3                Carrinho     NaN           1.0
# 3   4                   Skate   296.0           1.0
# 4   5                     NaN  3500.0           2.0
# 5   6           Monitor LG 19   450.0           2.0
# 6   7  O Diário de Anne Frank    45.0           NaN
# 7   8        O dia do Curinga    65.0           3.0
# 8   9        O mundo de Sofia     NaN           3.0
# 9  10      Através do Espelho    38.0           3.0

# %% [markdown]
# ### Filtragem de dados (por linha e coluna)

# %%
base_dados.loc[6]
# Out:
# id                                   7
# nome            O Diário de Anne Frank
# preco                             45.0
# id_categoria                       NaN
# Name: 6, dtype: object

# %%
base_dados.loc[6,'nome']
# Out:
# 'O Diário de Anne Frank'

# %%
filtro_1 = base_dados[(base_dados['preco']>100) & (base_dados['id_categoria']>1)]

# %%
filtro_1
# Out:
#    id           nome   preco  id_categoria
# 4   5            NaN  3500.0           2.0
# 5   6  Monitor LG 19   450.0           2.0

# %%
filtro_1[['id','preco']]
# Out:
#    id   preco
# 4   5  3500.0
# 5   6   450.0

# %% [markdown]
# ### Criação de colunas

# %%
base_dados
# Out:
#    id                    nome   preco  id_categoria  nova_coluna
# 0   1                    Bola    35.0           1.0            0
# 1   2                Patinete   120.0           1.0            0
# 2   3                Carrinho     NaN           1.0            0
# 3   4                   Skate   296.0           1.0            0
# 4   5                     NaN  3500.0           2.0            0
# 5   6           Monitor LG 19   450.0           2.0            0
# 6   7  O Diário de Anne Frank    45.0           NaN            0
# 7   8        O dia do Curinga    65.0           3.0            0
# 8   9        O mundo de Sofia     NaN           3.0            0
# 9  10      Através do Espelho    38.0           3.0            0

# %%
#EXECUTE SÓ PARA TESTE, MAS NÃO VAI FUNCIONAR!!!
if base_dados['preco']>50 | base_dados['preco']==50:
    base_dados['novo_coluna']='Deferido'
else:
    base_dados['novo_coluna']='Indeferido'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:305, in na_logical_op(x, y, op)
#     296 try:
#     297     # For exposition, write:
#     298     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     303     # Then Cases where this goes through without raising include:
#     304     #  (xint or xbool) and (yint or bool)
# --> 305     result = op(x, y)
#     306 except TypeError:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\roperator.py:58, in ror_(left, right)
#      57 def ror_(left, right):
# ---> 58     return operator.or_(right, left)
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
# ...

# %%
base_dados['novo_coluna'] = np.where((base_dados['preco']>50) | (base_dados['preco']==50),"Deferido","Indeferido")

# %%
base_dados
# Out:
#    id                    nome   preco  id_categoria novo_coluna
# 0   1                    Bola    35.0           1.0  Indeferido
# 1   2                Patinete   120.0           1.0    Deferido
# 2   3                Carrinho     NaN           1.0  Indeferido
# 3   4                   Skate   296.0           1.0    Deferido
# 4   5                     NaN  3500.0           2.0    Deferido
# 5   6           Monitor LG 19   450.0           2.0    Deferido
# 6   7  O Diário de Anne Frank    45.0           NaN  Indeferido
# 7   8        O dia do Curinga    65.0           3.0    Deferido
# 8   9        O mundo de Sofia     NaN           3.0  Indeferido
# 9  10      Através do Espelho    38.0           3.0  Indeferido

# %% [markdown]
# ### Exclusão de linhas e colunas

# %%
base_dados
# Out:
#    id                    nome   preco  id_categoria
# 0   1                    Bola    35.0           1.0
# 1   2                Patinete   120.0           1.0
# 2   3                Carrinho     NaN           1.0
# 3   4                   Skate   296.0           1.0
# 4   5                     NaN  3500.0           2.0
# 5   6           Monitor LG 19   450.0           2.0
# 6   7  O Diário de Anne Frank    45.0           NaN
# 7   8        O dia do Curinga    65.0           3.0
# 8   9        O mundo de Sofia     NaN           3.0
# 9  10      Através do Espelho    38.0           3.0

# %%
base_dados = base_dados.drop(['novo_coluna'],axis=1)

# %%
base_dados = base_dados.drop([9])

# %%
base_dados
# Out:
#    id                    nome   preco  id_categoria
# 0   1                    Bola    35.0           1.0
# 1   2                Patinete   120.0           1.0
# 2   3                Carrinho     NaN           1.0
# 3   4                   Skate   296.0           1.0
# 4   5                     NaN  3500.0           2.0
# 5   6           Monitor LG 19   450.0           2.0
# 6   7  O Diário de Anne Frank    45.0           NaN
# 7   8        O dia do Curinga    65.0           3.0
# 8   9        O mundo de Sofia     NaN           3.0
